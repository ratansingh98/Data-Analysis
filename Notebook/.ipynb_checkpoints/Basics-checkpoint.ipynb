# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Object Creation

# %%
s = pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101',periods =6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns= list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511
# 2013-01-04 -0.298874  1.209423 -0.661699 -1.553990
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950
# 2013-01-06 -0.564556  1.286948 -0.239251 -0.110625

# %%
df2 = pd.DataFrame({
    'A':1.,
    'B':pd.Timestamp('20130101'),
    'C':pd.Series(1,index=list(range(4)),dtype='float32'),
    'D':np.array([3]*4,dtype='int32'),
    'E':pd.Categorical(["test","train","test","train"]),
    'F':'foo'
})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-01  1.0  3   test  foo
# 1  1.0 2013-01-01  1.0  3  train  foo
# 2  1.0 2013-01-01  1.0  3   test  foo
# 3  1.0 2013-01-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# ## Viewing Data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511
# 2013-01-04 -0.298874  1.209423 -0.661699 -1.553990
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.298874  1.209423 -0.661699 -1.553990
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950
# 2013-01-06 -0.564556  1.286948 -0.239251 -0.110625

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.34544457e+00, -5.17379320e-01,  1.17952134e+00,
#          1.91773032e+00],
#        [-4.18107831e-01,  9.77590291e-01, -1.10544154e-05,
#          5.78463294e-01],
#        [-6.94884360e-01, -4.14689198e-01, -6.27795628e-01,
#          1.51510795e-01],
#        [-2.98873507e-01,  1.20942271e+00, -6.61699257e-01,
#         -1.55399048e+00],
#        [-3.75878417e-01, -5.97893076e-01, -3.90395618e-01,
#          1.32794970e+00],
#        [-5.64556155e-01,  1.28694823e+00, -2.39251212e-01,
#         -1.10625230e-01]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.616291  0.324000 -0.123272  0.385173
# std    0.384278  0.921074  0.684356  1.211255
# min   -1.345445 -0.597893 -0.661699 -1.553990
# 25%   -0.662302 -0.491707 -0.568446 -0.045091
# 50%   -0.491332  0.281451 -0.314823  0.364987
# 75%   -0.386436  1.151465 -0.059821  1.140578
# max   -0.298874  1.286948  1.179521  1.917730

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.345445   -0.418108   -0.694884   -0.298874   -0.375878   -0.564556
# B   -0.517379    0.977590   -0.414689    1.209423   -0.597893    1.286948
# C    1.179521   -0.000011   -0.627796   -0.661699   -0.390396   -0.239251
# D    1.917730    0.578463    0.151511   -1.553990    1.327950   -0.110625

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.917730  1.179521 -0.517379 -1.345445
# 2013-01-02  0.578463 -0.000011  0.977590 -0.418108
# 2013-01-03  0.151511 -0.627796 -0.414689 -0.694884
# 2013-01-04 -1.553990 -0.661699  1.209423 -0.298874
# 2013-01-05  1.327950 -0.390396 -0.597893 -0.375878
# 2013-01-06 -0.110625 -0.239251  1.286948 -0.564556

# %%
df.sort_values(by="B",ascending="False")
# Out:
#                    A         B         C         D
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463
# 2013-01-04 -0.298874  1.209423 -0.661699 -1.553990
# 2013-01-06 -0.564556  1.286948 -0.239251 -0.110625

# %%
print("----Max---")
print(df.max())
print("\n----Min---")
print(df.min())
print("\n----Mean---")
print(df.mean())
# Out:
# ----Max---
# A   -0.298874
# B    1.286948
# C    1.179521
# D    1.917730
# dtype: float64
#
# ----Min---
# A   -1.345445
# B   -0.597893
# C   -0.661699
# D   -1.553990
# dtype: float64
#
# ----Mean---
# A   -0.616291
# B    0.324000
# C   -0.123272
# D    0.385173
# dtype: float64

# %% [markdown]
# ## Selection

# %%
df['A']
# Out:
# 2013-01-01   -1.345445
# 2013-01-02   -0.418108
# 2013-01-03   -0.694884
# 2013-01-04   -0.298874
# 2013-01-05   -0.375878
# 2013-01-06   -0.564556
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511

# %% [markdown]
#                                                       Selection by Label

# %%
df.loc[dates[0]]
# Out:
# A   -1.345445
# B   -0.517379
# C    1.179521
# D    1.917730
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2013-01-01 -1.345445 -0.517379
# 2013-01-02 -0.418108  0.977590
# 2013-01-03 -0.694884 -0.414689
# 2013-01-04 -0.298874  1.209423
# 2013-01-05 -0.375878 -0.597893
# 2013-01-06 -0.564556  1.286948

# %%
df.loc['20130102':'20130104',['A','B']]
# Out:
#                    A         B
# 2013-01-02 -0.418108  0.977590
# 2013-01-03 -0.694884 -0.414689
# 2013-01-04 -0.298874  1.209423

# %%
df.loc['20130102',['A','B']]
# Out:
# A   -0.418108
# B    0.977590
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# -1.3454445682011955

# %%
df.at[dates[0],'A']
# Out:
# -1.3454445682011955

# %% [markdown]
#                                                    Selection by Position

# %%
df.iloc[3]
# Out:
# A   -0.298874
# B    1.209423
# C   -0.661699
# D   -1.553990
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:3]
# Out:
#                    A         B         C
# 2013-01-04 -0.298874  1.209423 -0.661699
# 2013-01-05 -0.375878 -0.597893 -0.390396

# %%
df.iloc[[1,2,4],[0,2]]
# Out:
#                    A         C
# 2013-01-02 -0.418108 -0.000011
# 2013-01-03 -0.694884 -0.627796
# 2013-01-05 -0.375878 -0.390396

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511

# %%
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.517379  1.179521
# 2013-01-02  0.977590 -0.000011
# 2013-01-03 -0.414689 -0.627796
# 2013-01-04  1.209423 -0.661699
# 2013-01-05 -0.597893 -0.390396
# 2013-01-06  1.286948 -0.239251

# %%
df.iloc[1,1]
# Out:
# 0.9775902911634871

# %% [markdown]
#                                                         Boolean Indexing

# %%
df[df.A>1]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df[df>0]
# Out:
#              A         B         C         D
# 2013-01-01 NaN       NaN  1.179521  1.917730
# 2013-01-02 NaN  0.977590       NaN  0.578463
# 2013-01-03 NaN       NaN       NaN  0.151511
# 2013-01-04 NaN  1.209423       NaN       NaN
# 2013-01-05 NaN       NaN       NaN  1.327950
# 2013-01-06 NaN  1.286948       NaN       NaN

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one','two','three','four','three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730    one
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463    one
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511    two
# 2013-01-04 -0.298874  1.209423 -0.661699 -1.553990  three
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950   four
# 2013-01-06 -0.564556  1.286948 -0.239251 -0.110625  three

# %%
df2[df2["E"].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511   two
# 2013-01-05 -0.375878 -0.597893 -0.390396  1.327950  four

# %%
df2[df2["E"].isin(['two','one'])]
# Out:
#                    A         B         C         D    E
# 2013-01-01 -1.345445 -0.517379  1.179521  1.917730  one
# 2013-01-02 -0.418108  0.977590 -0.000011  0.578463  one
# 2013-01-03 -0.694884 -0.414689 -0.627796  0.151511  two

# %% [markdown]
#                                                         Setting

# %%
s1 = pd.Series([1,2,3,4,5,6], index = pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F']=s1

# %%
df.at[dates[0],'A'] = 0

# %%
df.iat[0,1] =0

# %%
df.loc[:,'D'] = np.array([5]* len(df))

# %%
df
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000  1.179521  5  NaN
# 2013-01-02 -0.418108  0.977590 -0.000011  5  1.0
# 2013-01-03 -0.694884 -0.414689 -0.627796  5  2.0
# 2013-01-04 -0.298874  1.209423 -0.661699  5  3.0
# 2013-01-05 -0.375878 -0.597893 -0.390396  5  4.0
# 2013-01-06 -0.564556  1.286948 -0.239251  5  5.0

# %%
df2 = df.copy()

# %%
df2[df2 >0 ] =-df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -1.179521 -5  NaN
# 2013-01-02 -0.418108 -0.977590 -0.000011 -5 -1.0
# 2013-01-03 -0.694884 -0.414689 -0.627796 -5 -2.0
# 2013-01-04 -0.298874 -1.209423 -0.661699 -5 -3.0
# 2013-01-05 -0.375878 -0.597893 -0.390396 -5 -4.0
# 2013-01-06 -0.564556 -1.286948 -0.239251 -5 -5.0

# %% [markdown]
# # Missing Data

# %%
df1 = df.reindex(index=dates[0:4],columns = list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.179521  5  NaN  1.0
# 2013-01-02 -0.418108  0.977590 -0.000011  5  1.0  1.0
# 2013-01-03 -0.694884 -0.414689 -0.627796  5  2.0  NaN
# 2013-01-04 -0.298874  1.209423 -0.661699  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                    A        B         C  D    F    E
# 2013-01-02 -0.418108  0.97759 -0.000011  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  1.179521  5  5.0  1.0
# 2013-01-02 -0.418108  0.977590 -0.000011  5  1.0  1.0
# 2013-01-03 -0.694884 -0.414689 -0.627796  5  2.0  5.0
# 2013-01-04 -0.298874  1.209423 -0.661699  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# # Operations

# %% [markdown]
#                                                         Status

# %%
df.mean()
# Out:
# A   -0.392050
# B    0.410230
# C   -0.123272
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.544880
# 2013-01-02    1.311894
# 2013-01-03    1.052526
# 2013-01-04    1.649770
# 2013-01-05    1.527167
# 2013-01-06    2.096628
# Freq: D, dtype: float64

# %%
s= pd.Series([1,3,4,np.nan,6,8],index =dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    4.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -1.694884 -1.414689 -1.627796  4.0  1.0
# 2013-01-04 -3.298874 -1.790577 -3.661699  2.0  0.0
# 2013-01-05 -4.375878 -4.597893 -4.390396  1.0  0.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
#                                                         Apply

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  1.179521   5   NaN
# 2013-01-02 -0.418108  0.977590  1.179510  10   1.0
# 2013-01-03 -1.112992  0.562901  0.551715  15   3.0
# 2013-01-04 -1.411866  1.772324 -0.109985  20   6.0
# 2013-01-05 -1.787744  1.174431 -0.500380  25  10.0
# 2013-01-06 -2.352300  2.461379 -0.739631  30  15.0

# %%
df.apply(lambda x:x.max()-x.min())
# Out:
# A    0.694884
# B    1.884841
# C    1.841221
# D    0.000000
# F    4.000000
# dtype: float64

# %% [markdown]
#                                                     histogramming

# %%
s = pd.Series(np.random.randint(0,7,size=10))

# %%
s
# Out:
# 0    5
# 1    1
# 2    4
# 3    4
# 4    1
# 5    2
# 6    2
# 7    4
# 8    2
# 9    0
# dtype: int64

# %%
s.value_counts()
# Out:
# 4    3
# 2    3
# 1    2
# 5    1
# 0    1
# dtype: int64

# %% [markdown]
#                                                         String Methods

# %%
s = pd.Series(['A','B','C','Aaba','Baca',np.nan,'CABA','dog','cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %% [markdown]
# # Merge

# %% [markdown]
#                                                     Concat

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.918661 -0.410182  1.909183  1.709511
# 1  2.247861 -0.189973  0.988898  0.289681
# 2  0.605752 -1.404537  0.037948  1.300527
# 3 -0.322739  0.245533  0.603428 -1.161312
# 4  1.033305 -0.053625 -1.163804  1.228649
# 5 -0.426506  0.117690 -1.069841 -0.233592
# 6  2.113331  0.464658 -0.098947  0.004879
# 7  0.558209  0.751670  0.348789  0.468995
# 8  0.963153  0.246864 -1.617213 -0.804806
# 9 -0.076978  0.216447 -0.861054 -0.158934

# %%
pieces = [df[:3],df[3:7],df[7:1]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.918661 -0.410182  1.909183  1.709511
# 1  2.247861 -0.189973  0.988898  0.289681
# 2  0.605752 -1.404537  0.037948  1.300527
# 3 -0.322739  0.245533  0.603428 -1.161312
# 4  1.033305 -0.053625 -1.163804  1.228649
# 5 -0.426506  0.117690 -1.069841 -0.233592
# 6  2.113331  0.464658 -0.098947  0.004879

# %% [markdown]
#                                                 JOIN

# %%
left = pd.DataFrame({'key':['foo','foo'],'lval':[1,2]})

# %%
right = pd.DataFrame({'key':['foo','foo'],'rval':[4,5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key':['foo','bar'],'lval':[1,2]})

# %%
right = pd.DataFrame({'key':['foo','bar'],'rval':[4,5]})

# %%
pd.merge(left,right,on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %% [markdown]
#                                                    APPEND

# %%
df = pd.DataFrame(np.random.randn(8,4),columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0 -1.270895 -0.010213  0.123895 -0.395301
# 1 -0.459088  1.109025 -1.093956  0.357824
# 2 -1.261702  1.030625 -0.711207  1.234921
# 3  0.346796 -0.191078 -0.222609  1.138274
# 4 -1.732972  0.678500  0.270489  0.628535
# 5  0.434113 -0.260070 -1.251225 -0.373574
# 6 -0.668420  0.887660 -2.072279 -0.878177
# 7 -0.601888 -0.542369  2.382499  0.752724

# %%
s = df.iloc[3]

# %%
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -1.270895 -0.010213  0.123895 -0.395301
# 1 -0.459088  1.109025 -1.093956  0.357824
# 2 -1.261702  1.030625 -0.711207  1.234921
# 3  0.346796 -0.191078 -0.222609  1.138274
# 4 -1.732972  0.678500  0.270489  0.628535
# 5  0.434113 -0.260070 -1.251225 -0.373574
# 6 -0.668420  0.887660 -2.072279 -0.878177
# 7 -0.601888 -0.542369  2.382499  0.752724
# 8  0.346796 -0.191078 -0.222609  1.138274

# %% [markdown]
# # Grouping

# %%
df = pd.DataFrame({'A' : ['foo','bar','foo','bar',
                      'foo','bar','foo','foo'],
                   'B' : ['one','one','two','three',
                       'two','two','one','three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.667661  1.479562
# 1  bar    one  0.470886 -1.404842
# 2  foo    two -0.606111 -0.886558
# 3  bar  three  1.475096  0.999919
# 4  foo    two -0.805893 -0.889777
# 5  bar    two -0.036280 -0.397101
# 6  foo    one -1.028143  0.482552
# 7  foo  three  0.848093  0.136838

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar  1.909703 -0.802024
# foo -0.924394  0.322618

# %%
df.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.470886 -1.404842
#     three  1.475096  0.999919
#     two   -0.036280 -0.397101
# foo one   -0.360483  1.962114
#     three  0.848093  0.136838
#     two   -1.412004 -1.776335

# %% [markdown]
# # Reshaping

# %% [markdown]
#                                                 STACK

# %%
tuples = list(zip(*[['bar','bar','baz','baz',
                    'foo','foo','qux','qux'],
                   ['one','two','one','two',
                   'one', 'two', 'one', 'two']]))

# %%
index =  pd.MultiIndex.from_tuples(tuples, names = ['first','second'])

# %%
df = pd.DataFrame(np.random.randn(8,2),index = index, columns = ['A','B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.278418 -0.066131
#       two     1.163179 -0.577651
# baz   one     0.715760 -1.796202
#       two     0.061022 -0.095272

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.278418
#                B   -0.066131
#        two     A    1.163179
#                B   -0.577651
# baz    one     A    0.715760
#                B   -1.796202
#        two     A    0.061022
#                B   -0.095272
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.278418 -0.066131
#       two     1.163179 -0.577651
# baz   one     0.715760 -1.796202
#       two     0.061022 -0.095272

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.278418  1.163179
#       B -0.066131 -0.577651
# baz   A  0.715760  0.061022
#       B -1.796202 -0.095272

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.278418  0.715760
#        B -0.066131 -1.796202
# two    A  1.163179  0.061022
#        B -0.577651 -0.095272

# %% [markdown]
#                                             Pivot Tables

# %%
df = pd.DataFrame({'A': ['one','one','two','three']*3,
                  'B' : ['A','B','C',] * 4,
                  'C' : ['foo','foo','foo','bar','bar','bar']*2,
                  'D' : np.random.randn(12),
                  'E' : np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.002115 -0.110687
# 1     one  B  foo  0.872313  1.608193
# 2     two  C  foo  0.734842  0.095870
# 3   three  A  bar  0.759014  0.294147
# 4     one  B  bar  0.026028  0.454995
# 5     one  C  bar  1.256904 -2.224396
# 6     two  A  foo  0.152403 -0.447749
# 7   three  B  foo -1.273509 -0.295202
# 8     one  C  foo  0.374554  0.671435
# 9     one  A  bar  0.466754 -0.388132
# 10    two  B  bar -0.885637  1.628682
# 11  three  C  bar -0.629658  1.122066

# %%
pd.pivot_table(df, values='D',index = ['A','B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  0.466754 -0.002115
#       B  0.026028  0.872313
#       C  1.256904  0.374554
# three A  0.759014       NaN
#       B       NaN -1.273509
#       C -0.629658       NaN
# two   A       NaN  0.152403
#       B -0.885637       NaN
#       C       NaN  0.734842

# %% [markdown]
# # Times Series

# %%
rng = pd.date_range('1/1/2012', periods = 100, freq = 'S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    26572
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 00:00', periods = 5, freq = 'D')

# %%
ts = pd.Series(np.random.randn(len(rng)),rng)

# %%
ts
# Out:
# 2012-03-06   -0.438653
# 2012-03-07   -0.139761
# 2012-03-08    0.627518
# 2012-03-09   -1.015505
# 2012-03-10   -0.314801
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.438653
# 2012-03-07 00:00:00+00:00   -0.139761
# 2012-03-08 00:00:00+00:00    0.627518
# 2012-03-09 00:00:00+00:00   -1.015505
# 2012-03-10 00:00:00+00:00   -0.314801
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00   -0.438653
# 2012-03-06 19:00:00-05:00   -0.139761
# 2012-03-07 19:00:00-05:00    0.627518
# 2012-03-08 19:00:00-05:00   -1.015505
# 2012-03-09 19:00:00-05:00   -0.314801
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ls = pd.Series(np.random.randn(len(rng)),index=rng)

# %%
ts
# Out:
# 2012-03-06   -0.438653
# 2012-03-07   -0.139761
# 2012-03-08    0.627518
# 2012-03-09   -1.015505
# 2012-03-10   -0.314801
# Freq: D, dtype: float64

# %%
ps = ts.to_period()

# %%
ps
# Out:
# 2012-03-06   -0.438653
# 2012-03-07   -0.139761
# 2012-03-08    0.627518
# 2012-03-09   -1.015505
# 2012-03-10   -0.314801
# Freq: D, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-03-06   -0.438653
# 2012-03-07   -0.139761
# 2012-03-08    0.627518
# 2012-03-09   -1.015505
# 2012-03-10   -0.314801
# Freq: D, dtype: float64

# %%
prng = pd.period_range('1990Q1','2000Q4', freq= "Q-NOV")

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M','e')+1).asfreq('H','s')+9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -1.178579
# 1990-06-01 09:00   -0.493265
# 1990-09-01 09:00    0.314538
# 1990-12-01 09:00   -1.298202
# 1991-03-01 09:00    0.594804
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals

# %%
df = pd.DataFrame({"id": [1,2,3,4,5,6], "raw_grade": ['a','b','b','a','a','e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad","bad","medium","good","very good"])

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade", ascending= False)
# Out:
#    id raw_grade      grade
# 4   5         a  very good
# 3   4         a  very good
# 0   1         a  very good
# 2   3         b       good
# 1   2         b       good
# 5   6         e   very bad

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# # Plotting

# %%
ts = pd.Series(np.random.randn(1000), index = pd.date_range('1/1/2000', periods =1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000,4), index = ts.index,columns = ['A','B','C','D'])

# %%
df =df.cumsum()

# %%
df.plot()

# %% [markdown]
# # CSV

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A          B          C          D
# 0    2000-01-